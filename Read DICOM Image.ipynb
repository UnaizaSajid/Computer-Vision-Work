# %%
import cv2
import os
import time
import pydicom
import matplotlib.pyplot as plt
from pathlib import Path
from pydicom.filereader import dcmread
from skimage.transform import resize
from pydicom.data import get_testdata_files
img_size=250

fpath = r'C:\Users\Home\--------'
for i in os.listdir(fpath):
    ds = dcmread(str(fpath)+"\\"+ i, cv2.IMREAD_GRAYSCALE)
    data = ds.pixel_array
    IMG_PX_SIZE = 1048
    # resize to new size
    resized_img = resize(data, (IMG_PX_SIZE, IMG_PX_SIZE), anti_aliasing=True)
    print(resized_img.shape)
    print(ds.convert_pixel_data)
    fig = plt.figure(figsize=(10,6))
    plt.imshow(resized_img, cmap=plt.cm.gray)
    plt.show()
# Out:
# (1048, 1048)
# <bound method Dataset.convert_pixel_data of Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 194
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.9590.100.1.2.265647748413262733922850405400999282492
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.9590.100.1.2.265647748413262733922850405400999282492
# (0008, 0020) Study Date                          DA: ''
# (0008, 0023) Content Date                        DA: '20160503'
# (0008, 0030) Study Time                          TM: ''
# (0008, 0033) Content Time                        TM: '105950.914000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MG'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0010, 0010) Patient's Name                      PN: 'P_00038^P_00038'
# (0010, 0020) Patient ID                          LO: 'P_00038_LEFT_MLO.dcm'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0018, 0015) Body Part Examined                  CS: 'Left Breast'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'MathWorks'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'MATLAB'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.9590.100.1.2.384159464510350889125645400702639717613
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.9590.100.1.2.174390361112646747718661211471328897934
# (0020, 0010) Study ID                            SH: 'DDSM'
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0020) Patient Orientation                 CS: 'MLO'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 4728
# (0028, 0011) Columns                             US: 3064
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 65535
# (7fe0, 0010) Pixel Data                          OW: Array of 28973184 elements>
# (1048, 1048)
# <bound method Dataset.convert_pixel_data of Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 194
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.9590.100.1.2.378776769711002686209961163603436313519
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.9590.100.1.2.378776769711002686209961163603436313519
# (0008, 0020) Study Date                          DA: '20160807'
# (0008, 0023) Content Date                        DA: '20160503'
# (0008, 0030) Study Time                          TM: '161037'
# (0008, 0033) Content Time                        TM: '105435.478000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MG'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'full mammogram images'
# (0010, 0010) Patient's Name                      PN: 'Calc-Training_P_00005_RIGHT_CC'
# (0010, 0020) Patient ID                          LO: 'Calc-Training_P_00005_RIGHT_CC'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    UN: b'CBIS-DDSM '
# (0013, 1013) Private tag data                    UN: b'43352602'
# (0018, 0015) Body Part Examined                  CS: 'BREAST'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'MathWorks'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'MATLAB'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.9590.100.1.2.408909860712120272633130274602115723157
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.9590.100.1.2.47414316010368386519740343172775938548
# (0020, 0010) Study ID                            SH: 'DDSM'
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0020) Patient Orientation                 CS: 'CC'
# (0020, 0060) Laterality                          CS: 'R'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 5056
# (0028, 0011) Columns                             US: 2761
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 65535
# (7fe0, 0010) Pixel Data                          OW: Array of 27919232 elements>
# (1048, 1048)
# <bound method Dataset.convert_pixel_data of Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 194
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.9590.100.1.2.338899151111305765125644107920616871552
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.9590.100.1.2.338899151111305765125644107920616871552
# (0008, 0020) Study Date                          DA: '20170906'
# (0008, 0023) Content Date                        DA: '20160503'
# (0008, 0030) Study Time                          TM: '082235'
# (0008, 0033) Content Time                        TM: '105437.757000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MG'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'ROI mask images'
# (0010, 0010) Patient's Name                      PN: 'Calc-Training_P_00005_RIGHT_CC_1'
# (0010, 0020) Patient ID                          LO: 'Calc-Training_P_00005_RIGHT_CC_1'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    UN: b'CBIS-DDSM '
# (0013, 1013) Private tag data                    UN: b'43352602'
# (0018, 0015) Body Part Examined                  CS: 'BREAST'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'MathWorks'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'MATLAB'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.9590.100.1.2.328778919012412769218080124214088709081
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.9590.100.1.2.393344010211719049419601138200355094682
# (0020, 0010) Study ID                            SH: 'DDSM'
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0020) Patient Orientation                 CS: 'CC'
# (0020, 0060) Laterality                          CS: 'R'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 5056
# (0028, 0011) Columns                             US: 2761
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 255
# (7fe0, 0010) Pixel Data                          OW: Array of 13959616 elements>
# (1048, 1048)
# <bound method Dataset.convert_pixel_data of Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 194
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.6.1.4.1.9590.100.1.2.344560194211255710311153402222519334809
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.40.0.13.1.1.1
# (0002, 0013) Implementation Version Name         SH: 'dcm4che-1.4.35'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.9590.100.1.2.344560194211255710311153402222519334809
# (0008, 0020) Study Date                          DA: '20160807'
# (0008, 0023) Content Date                        DA: '20160503'
# (0008, 0030) Study Time                          TM: '161039'
# (0008, 0033) Content Time                        TM: '105440.625000'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MG'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'full mammogram images'
# (0010, 0010) Patient's Name                      PN: 'Calc-Training_P_00005_RIGHT_MLO'
# (0010, 0020) Patient ID                          LO: 'Calc-Training_P_00005_RIGHT_MLO'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: ''
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    UN: b'CBIS-DDSM '
# (0013, 1013) Private tag data                    UN: b'43352602'
# (0018, 0015) Body Part Examined                  CS: 'BREAST'
# (0018, 1016) Secondary Capture Device Manufactur LO: 'MathWorks'
# (0018, 1018) Secondary Capture Device Manufactur LO: 'MATLAB'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.9590.100.1.2.427517897311902339923511678883689433338
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.9590.100.1.2.250596608311207922527805669693579696727
# (0020, 0010) Study ID                            SH: 'DDSM'
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0020) Patient Orientation                 CS: 'MLO'
# (0020, 0060) Laterality                          CS: 'R'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 5386
# (0028, 0011) Columns                             US: 2836
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0106) Smallest Image Pixel Value          US: 0
# (0028, 0107) Largest Image Pixel Value           US: 65535
# (7fe0, 0010) Pixel Data                          OW: Array of 30549392 elements>
